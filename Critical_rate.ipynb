# %%
import statsmodels.api as sm
import numpy as np
from statsmodels.tools.tools import add_constant
import pandas as pd
import statsmodels
df = pd.read_csv("C:\\Users\\Samir Prasun\\Desktop\\Book\\Critical_Oil_Rate.csv")
df.head()
# Out:
#    Fracture effective permeability  Matrix permeability  Mobility  \
# 0                              500                  5.0         3
# 1                              500                  5.0         3
# 2                              500                  5.0         3
# 3                              500                  5.0         3
# 4                              500                  5.0         3
#
#    Fracture spacing  drainage radius  Anisotropy ratio  Penetration ratio  \
# 0               0.1              400                 1                0.5
# 1               0.1              400                10                0.5
# 2               0.1             2000                 1                0.5
# 3               0.1             2000                10                0.5
# 4              18.0              400                 1                0.5
#
#    Critical Oil Rate
# 0               22.7
# 1               19.4
# 2               18.9
# 3               18.2
# 4               22.7

# %%
df.describe()
# Out:
#        Fracture effective permeability  Matrix permeability   Mobility  \
# count                        62.000000            62.000000  62.000000
# mean                        712.903226            12.761290   2.967742
# std                         654.238105            18.489424   1.279956
# min                         100.000000             0.100000   1.000000
# 25%                         500.000000             5.000000   3.000000
# 50%                         500.000000             5.000000   3.000000
# 75%                         500.000000             5.000000   3.000000
# max                        2000.000000            50.000000   5.000000
#
#        Fracture spacing  drainage radius  Anisotropy ratio  Penetration ratio  \
# count         62.000000        62.000000         62.000000          62.000000
# mean           7.180645      1077.419355          5.193548           0.529032
# std            5.810246       511.320808          2.833284           0.145858
# min            0.100000       400.000000          1.000000           0.350000
# 25%            6.000000      1000.000000          5.000000           0.500000
# 50%            6.000000      1000.000000          5.000000           0.500000
# 75%            6.000000      1000.000000          5.000000           0.500000
# max           18.000000      2000.000000         10.000000           0.800000
#
#        Critical Oil Rate
# count          62.000000
# mean           33.854839
# std            43.424650
# min             1.800000
# 25%            10.275000
# 50%            19.000000
# 75%            47.000000
# max           240.000000

# %%
Kf = df.iloc[:,0].values
Km = df.iloc[:,1].values
M = df.iloc[:,2].values
Sp=df.iloc[:,3].values
re=df.iloc[:,4].values
I=df.iloc[:,5].values
p=df.iloc[:,6].values
Cr=df.iloc[:,7].values
A=re/40*(I)**0.5
Y=Cr/(0.0783*(10**-4)*(Kf+Km*0.63)*40**2*(1-p**2)*(64-52)/(0.7*M)/1.1)

df['Aspect_ratio']=A
df['Normalized_criticalrate']=Y

df.head()
# Out:
#    Fracture effective permeability  Matrix permeability  Mobility  \
# 0                              500                  5.0         3
# 1                              500                  5.0         3
# 2                              500                  5.0         3
# 3                              500                  5.0         3
# 4                              500                  5.0         3
#
#    Fracture spacing  drainage radius  Anisotropy ratio  Penetration ratio  \
# 0               0.1              400                 1                0.5
# 1               0.1              400                10                0.5
# 2               0.1             2000                 1                0.5
# 3               0.1             2000                10                0.5
# 4              18.0              400                 1                0.5
#
#    Critical Oil Rate  Aspect_ratio  Normalized_criticalrate
# 0               22.7     10.000000                 0.924307
# 1               19.4     31.622777                 0.789936
# 2               18.9     50.000000                 0.769577
# 3               18.2    158.113883                 0.741074
# 4               22.7     10.000000                 0.924307

# %%
x=1/A
X = sm.add_constant(x) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     339.5
# Date:                Sun, 03 May 2020   Prob (F-statistic):           2.21e-26
# Time:                        08:24:14   Log-Likelihood:                 170.01
# No. Observations:                  62   AIC:                            -336.0
# Df Residuals:                      60   BIC:                            -331.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7277      0.003    214.698      0.000       0.721       0.734
# x1             1.9969      0.108     18.426      0.000       1.780       2.214
# ==============================================================================
# Omnibus:                      119.548   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5122.268
# Skew:                          -6.193   Prob(JB):                         0.00
# Kurtosis:                      45.772   Cond. No.                         53.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
